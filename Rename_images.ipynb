# %%
import os

# %%
images_folder = "/Users/IkeMercado/Desktop/USM/2019-2/LabModelacion/lab_modelacion_real/images/ImagesforVideo/"

# %%
dummy = os.listdir(images_folder)
os.chdir(images_folder)
i = 1

# %%
dummy
# Out:
# ['.DS_Store',
#  '01.tiff',
#  '02.tiff',
#  '03.tiff',
#  '04.tiff',
#  '05.tiff',
#  '06.tiff',
#  '07.tiff',
#  '08.tiff',
#  '09.tiff',
#  '10.tiff',
#  '11.tiff',
#  '12.tiff',
#  '13.tiff',
#  '14.tiff',
#  '15.tiff',
#  '16.tiff',
#  '17.tiff',
#  '18.tiff',
#  '19.tiff',
#  '20.tiff',
#  '21.tiff',
#  '22.tiff',
#  '23.tiff',
#  '24.tiff',
#  '25.tiff',
#  '26.tiff',
#  '27.tiff',
#  '28.tiff',
#  '29.tiff',
#  '30.tiff',
#  '31.tiff',
#  '32.tiff',
#  '33.tiff',
#  '34.tiff',
#  '35.tiff',
#  '36.tiff',
#  '37.tiff',
#  '38.tiff',
#  '39.tiff',
#  '40.tiff',
#  '41.tiff',
#  '42.tiff',
#  '43.tiff',
#  '44.tiff',
#  '45.tiff',
#  '46.tiff',
#  '47.tiff',
#  '48.tiff',
#  '49.tiff',
#  '50.tiff',
#  '51.tiff',
#  '52.tiff',
#  '53.tiff',
#  '54.tiff',
#  '55.tiff',
#  '56.tiff',
#  '57.tiff',
#  '58.tiff',
#  '59.tiff',
#  '60.tiff',
#  '61.tiff',
#  '62.tiff',
#  '63.tiff',
#  '64.tiff',
#  '65.tiff',
#  '66.tiff',
#  '67.tiff',
#  '68.tiff',
#  '69.tiff',
#  '70.tiff',
# ...

# %%
for filename in dummy:
    name = "002 transmitted-"+str(i)+" (arrastrado).tiff"
    print(f"filename = {filename}  name = {name}")
    print(filename == name)
    if filename == name:
        if i < 10:
            os.rename(name,"0"+str(i)+".tiff")
        else:
            os.rename(name,str(i)+".tiff")
        i += 1
# Out:
# filename = .DS_Store  name = 002 transmitted-1 (arrastrado).tiff
# False
# filename = 002 transmitted-1 (arrastrado).tiff  name = 002 transmitted-1 (arrastrado).tiff
# True
# filename = 002 transmitted-2 (arrastrado).tiff  name = 002 transmitted-2 (arrastrado).tiff
# True
# filename = 002 transmitted-3 (arrastrado).tiff  name = 002 transmitted-3 (arrastrado).tiff
# True
# filename = 002 transmitted-4 (arrastrado).tiff  name = 002 transmitted-4 (arrastrado).tiff
# True
# filename = 002 transmitted-5 (arrastrado).tiff  name = 002 transmitted-5 (arrastrado).tiff
# True
# filename = 002 transmitted-6 (arrastrado).tiff  name = 002 transmitted-6 (arrastrado).tiff
# True
# filename = 002 transmitted-7 (arrastrado).tiff  name = 002 transmitted-7 (arrastrado).tiff
# True
# filename = 002 transmitted-8 (arrastrado).tiff  name = 002 transmitted-8 (arrastrado).tiff
# True
# filename = 002 transmitted-9 (arrastrado).tiff  name = 002 transmitted-9 (arrastrado).tiff
# True
# ...

# %%
i = 10

# %%
for filename in dummy:
    name = "002 transmitted-"+str(i)+" (arrastrado).tiff"
    if filename == name:
        if i < 10:
            os.rename(name,"0"+str(i)+".tiff")
        else:
            os.rename(name,str(i)+".tiff")
        i += 1

# %%
i = 1

# %%
 for filename in dummy:
    if i < 10:
            name = "0"+str(i)+".tiff"
    else:
            name = str(i) + ".tiff"
    print(f"filename = {filename}  name = {name}")
    print(filename == name)
    if filename == name:
        os.rename(name,"002 transmitted-"+str(i)+" (arrastrado).tiff")
        i += 1
# Out:
# filename = .DS_Store  name = 01.tiff
# False
# filename = 002 transmitted-10 (arrastrado).tiff  name = 01.tiff
# False
# filename = 002 transmitted-11 (arrastrado).tiff  name = 01.tiff
# False
# filename = 002 transmitted-12 (arrastrado).tiff  name = 01.tiff
# False
# filename = 002 transmitted-13 (arrastrado).tiff  name = 01.tiff
# False
# filename = 002 transmitted-14 (arrastrado).tiff  name = 01.tiff
# False
# filename = 002 transmitted-15 (arrastrado).tiff  name = 01.tiff
# False
# filename = 002 transmitted-16 (arrastrado).tiff  name = 01.tiff
# False
# filename = 002 transmitted-17 (arrastrado).tiff  name = 01.tiff
# False
# filename = 002 transmitted-18 (arrastrado).tiff  name = 01.tiff
# False
# filename = 002 transmitted-19 (arrastrado).tiff  name = 01.tiff
# False
# filename = 002 transmitted-20 (arrastrado).tiff  name = 01.tiff
# False
# filename = 002 transmitted-21 (arrastrado).tiff  name = 01.tiff
# False
# ...

# %%
i
# Out:
# 1

# %%
i
# Out:
# 1
